# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('results.txt')
df.columns = ['sudoku','rec','bt1','bt2']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29998 entries, 0 to 29997
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sudoku  29998 non-null  int64
#  1   rec     29998 non-null  float64
#  2   bt1     29998 non-null  float64
#  3   bt2     29998 non-null  float64
# dtypes: float64(3), int64(1)
# memory usage: 937.6 KB

# %%
df.mean()
# Out:
# sudoku    15000.500000
# rec           1.266451
# bt1           1.093113
# bt2           0.499677
# dtype: float64

# %%
sns.histplot(data=df, x="rec",color="blue", bins = 2000, label="Recursive")
sns.histplot(data=df, x="bt1",color="green", bins = 2000, label="Slow Backtrack")
sns.histplot(data=df, x="bt2",color="red", bins = 2000, label="Quick Backtrack")
plt.yscale('log')
plt.ylim([1, 10000])
plt.xlim([0, 15])
plt.legend()
plt.xlabel('Solve Time [ms]')
# Out:
# Text(0.5, 0, 'Solve Time [ms]')

# %%
sns.histplot(data=df, x="rec",color="blue", bins = 10000, label="Recursive")
sns.histplot(data=df, x="bt1",color="green", bins = 10000, label="Slow Backtrack")
sns.histplot(data=df, x="bt2",color="red", bins = 10000, label="Quick Backtrack")
plt.yscale('log')
plt.ylim([1, 100000])
plt.xlim([0, 3])
plt.legend()
plt.xlabel('Solve Time [ms]')
# Out:
# Text(0.5, 0, 'Solve Time [ms]')
